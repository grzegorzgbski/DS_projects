# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=500, n_features=2, centers=8, cluster_std=1.8, random_state=101)

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=8)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=8, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[-9.49621083, -6.53309985],
#        [ 5.3228585 , -6.80773803],
#        [ 0.03688004,  2.28889965],
#        [-2.98618506,  8.08695311],
#        [-6.26091446,  5.54214794],
#        [ 4.04840477,  6.88020916],
#        [ 1.34091196, -3.47914447],
#        [ 9.91119368, -5.31031903]])

# %%
kmeans.labels_
# Out:
# array([6, 6, 5, 2, 1, 2, 1, 4, 2, 0, 5, 1, 1, 3, 6, 2, 1, 5, 1, 4, 4, 3, 0,
#        1, 0, 6, 2, 7, 2, 0, 5, 2, 3, 5, 5, 1, 2, 7, 1, 0, 6, 1, 2, 6, 5, 2,
#        2, 3, 3, 5, 6, 6, 1, 0, 1, 3, 7, 2, 7, 1, 7, 6, 3, 4, 4, 4, 7, 6, 7,
#        2, 0, 0, 3, 4, 2, 2, 0, 1, 3, 5, 1, 7, 5, 3, 5, 7, 7, 6, 4, 1, 6, 4,
#        4, 5, 3, 4, 6, 7, 0, 0, 0, 2, 0, 3, 5, 7, 0, 0, 1, 2, 4, 6, 6, 7, 6,
#        4, 4, 0, 1, 6, 1, 6, 3, 1, 6, 7, 5, 1, 0, 1, 1, 6, 0, 7, 6, 2, 6, 3,
#        3, 4, 6, 7, 1, 5, 6, 4, 4, 2, 5, 7, 6, 7, 4, 1, 6, 6, 1, 3, 0, 7, 7,
#        1, 7, 3, 2, 3, 3, 1, 7, 6, 3, 4, 7, 2, 7, 4, 6, 1, 7, 6, 2, 7, 3, 5,
#        5, 3, 5, 2, 5, 6, 4, 1, 5, 6, 4, 0, 0, 3, 2, 4, 6, 0, 6, 4, 4, 5, 4,
#        0, 3, 4, 6, 4, 5, 3, 0, 5, 1, 6, 0, 7, 4, 3, 3, 6, 4, 2, 5, 0, 2, 5,
#        0, 4, 4, 2, 6, 2, 1, 1, 4, 1, 6, 4, 2, 4, 0, 2, 6, 2, 5, 5, 4, 0, 2,
#        0, 6, 4, 4, 3, 2, 7, 6, 4, 5, 2, 4, 2, 7, 6, 0, 1, 4, 3, 6, 3, 7, 6,
#        1, 2, 6, 4, 2, 6, 0, 4, 3, 5, 4, 2, 6, 3, 4, 3, 1, 4, 1, 3, 4, 2, 4,
#        5, 2, 5, 1, 5, 5, 4, 0, 2, 7, 2, 7, 3, 2, 0, 4, 5, 4, 6, 0, 4, 7, 6,
#        0, 1, 0, 3, 0, 5, 5, 2, 4, 7, 5, 5, 2, 6, 6, 5, 6, 0, 2, 4, 5, 7, 5,
#        0, 6, 5, 5, 7, 2, 1, 3, 6, 7, 6, 2, 2, 5, 1, 2, 2, 0, 0, 2, 7, 4, 5,
#        5, 3, 2, 3, 4, 1, 7, 4, 7, 1, 2, 6, 1, 0, 2, 0, 0, 0, 0, 3, 6, 1, 1,
#        2, 5, 5, 1, 5, 6, 4, 4, 7, 0, 6, 4, 5, 3, 6, 7, 0, 7, 1, 2, 4, 6, 7,
#        1, 0, 0, 0, 5, 2, 0, 4, 2, 2, 6, 6, 2, 2, 6, 6, 1, 3, 7, 5, 5, 1, 4,
#        6, 0, 1, 7, 4, 3, 6, 2, 4, 3, 0, 6, 0, 3, 2, 5, 7, 7, 3, 7, 3, 1, 1,
#        0, 3, 7, 3, 7, 1, 7, 7, 5, 7, 6, 0, 7, 0, 3, 7, 4, 3, 6, 4, 4, 6, 3,
#        0, 7, 0, 0, 1, 3, 0, 2, 2, 3, 5, 4, 2, 4, 5, 2, 1], dtype=int32)

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')

# %%
fig , (ax1,ax2) = plt.subplots(1,2, sharey=True, figsize=(22,8))
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')
